# %% [markdown]
# # Employee Eval Part 3:
#
# In this ntoebook, We vary the temperature to pick optimal one

# %%
#pip installing:
# %pip install langchain
# %pip install langchain_community
# %pip install langchain_huggingface
# %pip install langchain_pinecone
# %pip install pinecone
# %pip install pinecone-client
# %pip install dotenv
# %pip install streamlit
# %pip install pymupdf
# %pip install -qU langchain_community wikipedia
# %pip install --upgrade --quiet langchain-text-splitters tiktoken
# %pip install difflib
# %pip install cohere
# %pip install cohere


import os
import langchain #its giving module not found error
import langchain_community
import langchain_huggingface
import langchain_pinecone
import pinecone
import dotenv
import streamlit as st

# Additional Imports (loading document):
from langchain.document_loaders import PyMuPDFLoader
from langchain.text_splitter import CharacterTextSplitter

#pinecone etc (storage of ducments):
from pinecone import Pinecone, ServerlessSpec
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_pinecone import PineconeVectorStore
from uuid import uuid4

#hugging face etc (for generation):
from langchain_huggingface import HuggingFaceEndpoint
from langchain import PromptTemplate
from langchain.schema.runnable import RunnablePassthrough
from langchain.schema.output_parser import StrOutputParser
from langchain_core.runnables import RunnableLambda

#memory imports
#I used these documentations: https://python.langchain.com/v0.1/docs/use_cases/chatbots/memory_management/ , https://python.langchain.com/v0.1/docs/modules/memory/types/buffer/ , https://python.langchain.com/v0.1/docs/modules/memory/
from langchain.memory import ConversationBufferMemory
from langchain.chains import LLMChain
from langchain.chains import create_history_aware_retriever #new
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

#caching imports:
from difflib import SequenceMatcher

from langchain.text_splitter import CharacterTextSplitter
from langchain_text_splitters import TokenTextSplitter
#for timing the retrivals
import time

#for parsing:
import re

#for cohere:
import cohere
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.11)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.11.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.24 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.24)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.10.3)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.24->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.24->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.24->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.24->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.2.2)
# Collecting langchain_community
#   Downloading langchain_community-0.3.12-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (3.11.10)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain_community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting langchain<0.4.0,>=0.3.12 (from langchain_community)
#   Downloading langchain-0.3.12-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core<0.4.0,>=0.3.25 (from langchain_community)
#   Downloading langchain_core-0.3.25-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.2.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (1.26.4)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain_community)
#   Downloading pydantic_settings-2.7.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.18.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.3 (from langchain<0.4.0,>=0.3.12->langchain_community)
#   Downloading langchain_text_splitters-0.3.3-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.12->langchain_community) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.25->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.25->langchain_community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.25->langchain_community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain_community) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain_community) (1.0.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain_community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain_community) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain_community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.25->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.12->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.12->langchain_community) (2.27.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain_community) (1.2.2)
# Downloading langchain_community-0.3.12-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 30.2 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading langchain-0.3.12-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 25.3 MB/s eta 0:00:00
# Downloading langchain_core-0.3.25-py3-none-any.whl (411 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.2/411.2 kB 21.3 MB/s eta 0:00:00
# Downloading pydantic_settings-2.7.0-py3-none-any.whl (29 kB)
# Downloading langchain_text_splitters-0.3.3-py3-none-any.whl (27 kB)
# Downloading marshmallow-3.23.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.3 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-core, langchain-text-splitters, langchain, langchain_community
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.24
#     Uninstalling langchain-core-0.3.24:
#       Successfully uninstalled langchain-core-0.3.24
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.2
#     Uninstalling langchain-text-splitters-0.3.2:
#       Successfully uninstalled langchain-text-splitters-0.3.2
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.11
#     Uninstalling langchain-0.3.11:
#       Successfully uninstalled langchain-0.3.11
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-0.3.12 langchain-core-0.3.25 langchain-text-splitters-0.3.3 langchain_community-0.3.12 marshmallow-3.23.1 mypy-extensions-1.0.0 pydantic-settings-2.7.0 python-dotenv-1.0.1 typing-inspect-0.9.0
# Collecting langchain_huggingface
#   Downloading langchain_huggingface-0.1.2-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface) (0.26.5)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface) (0.3.25)
# Requirement already satisfied: sentence-transformers>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface) (3.2.1)
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface) (0.20.3)
# Requirement already satisfied: transformers>=4.39.0 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface) (4.46.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (4.66.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (2.10.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (9.0.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.13.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (11.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.39.0->langchain_huggingface) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.39.0->langchain_huggingface) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.39.0->langchain_huggingface) (0.4.5)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (2024.8.30)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (3.5.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.0.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_huggingface) (1.2.2)
# Downloading langchain_huggingface-0.1.2-py3-none-any.whl (21 kB)
# Installing collected packages: langchain_huggingface
# Successfully installed langchain_huggingface-0.1.2
# Collecting langchain_pinecone
#   Downloading langchain_pinecone-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting aiohttp<3.10,>=3.9.5 (from langchain_pinecone)
#   Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in /usr/local/lib/python3.10/dist-packages (from langchain_pinecone) (0.3.25)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain_pinecone) (1.26.4)
# Collecting pinecone-client<6.0.0,>=5.0.0 (from langchain_pinecone)
#   Downloading pinecone_client-5.0.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (1.18.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (4.0.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3->langchain_pinecone) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3->langchain_pinecone) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3->langchain_pinecone) (0.2.2)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3->langchain_pinecone) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3->langchain_pinecone) (2.10.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3->langchain_pinecone) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3->langchain_pinecone) (4.12.2)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.10/dist-packages (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone) (2024.8.30)
# Collecting pinecone-plugin-inference<2.0.0,>=1.0.3 (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone)
#   Downloading pinecone_plugin_inference-1.1.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.10/dist-packages (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone) (4.66.6)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone) (2.2.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain_pinecone) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3->langchain_pinecone) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3->langchain_pinecone) (3.10.12)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3->langchain_pinecone) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3->langchain_pinecone) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.3->langchain_pinecone) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.3->langchain_pinecone) (2.27.1)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp<3.10,>=3.9.5->langchain_pinecone) (3.10)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp<3.10,>=3.9.5->langchain_pinecone) (0.2.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3->langchain_pinecone) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3->langchain_pinecone) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3->langchain_pinecone) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3->langchain_pinecone) (3.4.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3->langchain_pinecone) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3->langchain_pinecone) (1.2.2)
# Downloading langchain_pinecone-0.2.0-py3-none-any.whl (11 kB)
# Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 54.9 MB/s eta 0:00:00
# Downloading pinecone_client-5.0.1-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.8/244.8 kB 21.8 MB/s eta 0:00:00
# Downloading pinecone_plugin_inference-1.1.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 7.1 MB/s eta 0:00:00
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Installing collected packages: pinecone-plugin-interface, pinecone-plugin-inference, pinecone-client, aiohttp, langchain_pinecone
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.10
#     Uninstalling aiohttp-3.11.10:
#       Successfully uninstalled aiohttp-3.11.10
# Successfully installed aiohttp-3.9.5 langchain_pinecone-0.2.0 pinecone-client-5.0.1 pinecone-plugin-inference-1.1.0 pinecone-plugin-interface-0.0.7
# Collecting pinecone
#   Downloading pinecone-5.4.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.10/dist-packages (from pinecone) (2024.8.30)
# Collecting pinecone-plugin-inference<4.0.0,>=2.0.0 (from pinecone)
#   Downloading pinecone_plugin_inference-3.1.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from pinecone) (2.8.2)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.10/dist-packages (from pinecone) (4.66.6)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from pinecone) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from pinecone) (2.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Downloading pinecone-5.4.2-py3-none-any.whl (427 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.3/427.3 kB 27.0 MB/s eta 0:00:00
# Downloading pinecone_plugin_inference-3.1.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 8.4 MB/s eta 0:00:00
# Installing collected packages: pinecone-plugin-inference, pinecone
#   Attempting uninstall: pinecone-plugin-inference
#     Found existing installation: pinecone-plugin-inference 1.1.0
#     Uninstalling pinecone-plugin-inference-1.1.0:
#       Successfully uninstalled pinecone-plugin-inference-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pinecone-client 5.0.1 requires pinecone-plugin-inference<2.0.0,>=1.0.3, but you have pinecone-plugin-inference 3.1.0 which is incompatible.
# Successfully installed pinecone-5.4.2 pinecone-plugin-inference-3.1.0
# Requirement already satisfied: pinecone-client in /usr/local/lib/python3.10/dist-packages (5.0.1)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2024.8.30)
# Collecting pinecone-plugin-inference<2.0.0,>=1.0.3 (from pinecone-client)
#   Using cached pinecone_plugin_inference-1.1.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (0.0.7)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (4.66.6)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2.2.3)
# Using cached pinecone_plugin_inference-1.1.0-py3-none-any.whl (85 kB)
# Installing collected packages: pinecone-plugin-inference
#   Attempting uninstall: pinecone-plugin-inference
#     Found existing installation: pinecone-plugin-inference 3.1.0
#     Uninstalling pinecone-plugin-inference-3.1.0:
#       Successfully uninstalled pinecone-plugin-inference-3.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pinecone 5.4.2 requires pinecone-plugin-inference<4.0.0,>=2.0.0, but you have pinecone-plugin-inference 1.1.0 which is incompatible.
# Successfully installed pinecone-plugin-inference-1.1.0
# Collecting dotenv
#   Downloading dotenv-0.0.5.tar.gz (2.4 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting streamlit
#   Downloading streamlit-1.41.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (11.0.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.25.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.12.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.1.43)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.41.1-py2.py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 91.9 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 102.0 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.9 MB/s eta 0:00:00
# Installing collected packages: watchdog, pydeck, streamlit
# Successfully installed pydeck-0.9.1 streamlit-1.41.1 watchdog-6.0.0
# Collecting pymupdf
#   Downloading pymupdf-1.25.1-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.25.1-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 65.3 MB/s eta 0:00:00
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.25.1
#   Preparing metadata (setup.py) ... done
#   Building wheel for wikipedia (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 45.7 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement difflib (from versions: none)
# ERROR: No matching distribution found for difflib
# Collecting cohere
#   Downloading cohere-5.13.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere)
#   Downloading fastavro-1.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: httpx>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.28.1)
# Requirement already satisfied: httpx-sse==0.4.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.4.0)
# Requirement already satisfied: numpy<2.0,>=1.26 in /usr/local/lib/python3.10/dist-packages (from cohere) (1.26.4)
# Collecting parameterized<0.10.0,>=0.9.0 (from cohere)
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pydantic>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.10.3)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.27.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.32.3)
# Requirement already satisfied: tokenizers<1,>=0.15 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.20.3)
# Collecting types-requests<3.0.0,>=2.0.0 (from cohere)
#   Downloading types_requests-2.32.0.20241016-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (4.12.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.21.2->cohere) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.2->cohere) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (2.2.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers<1,>=0.15->cohere) (0.26.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (4.66.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.21.2->cohere) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.21.2->cohere) (1.2.2)
# Downloading cohere-5.13.3-py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.9/249.9 kB 19.1 MB/s eta 0:00:00
# Downloading fastavro-1.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 76.4 MB/s eta 0:00:00
# Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Downloading types_requests-2.32.0.20241016-py3-none-any.whl (15 kB)
# Installing collected packages: types-requests, parameterized, fastavro, cohere
# Successfully installed cohere-5.13.3 fastavro-1.9.7 parameterized-0.9.0 types-requests-2.32.0.20241016
# Requirement already satisfied: cohere in /usr/local/lib/python3.10/dist-packages (5.13.3)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /usr/local/lib/python3.10/dist-packages (from cohere) (1.9.7)
# Requirement already satisfied: httpx>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.28.1)
# Requirement already satisfied: httpx-sse==0.4.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.4.0)
# Requirement already satisfied: numpy<2.0,>=1.26 in /usr/local/lib/python3.10/dist-packages (from cohere) (1.26.4)
# Requirement already satisfied: parameterized<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.9.0)
# Requirement already satisfied: pydantic>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.10.3)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.27.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.32.3)
# Requirement already satisfied: tokenizers<1,>=0.15 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.20.3)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.32.0.20241016)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (4.12.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.21.2->cohere) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.2->cohere) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (2.2.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers<1,>=0.15->cohere) (0.26.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (4.66.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.21.2->cohere) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.21.2->cohere) (1.2.2)

# %%
# Replace with the API keys you need
HUGGINGFACE_API_KEY = ""
PINECONE_API_KEY = ""
COHERE_API_KEY = ""

env_content = f"""
HUGGINGFACE_API_KEY={HUGGINGFACE_API_KEY}
PINECONE_API_KEY={PINECONE_API_KEY}
COHERE_API_KEY={COHERE_API_KEY}
"""

with open(".env", "w") as file:
    file.write(env_content)

print("Environment variables are saved to .env file.")

dotenv.load_dotenv()
# Out:
# Environment variables are saved to .env file.
# True

# %% [markdown]
# # Low Temperature: (0.2)

# %%
class EmployeeChatBot:
    # TODO: To be implemented
    def __init__(self):
        #loading variables:
        self.combined_text = ""
        self.CHUNK_SIZE = 256
        self.CHUNK_OVERLAP = 0.50
        #storing variables:
        self.pc = Pinecone(api_key=os.environ.get("PINECONE_API_KEY"))
        self.index_name = "employee-queries-db" #keep the name small
        self.embeddings = HuggingFaceEmbeddings()
        self.index = self.pc.Index(self.index_name) #Remember, i can do this because i have already once created this index, else create index first
        self.vector_store = PineconeVectorStore(index=self.index, embedding=self.embeddings)
        # generating variables
        self.retriever = self.vector_store.as_retriever( search_type="similarity_score_threshold", search_kwargs={"k": 3, "score_threshold": 0.5},) #tunable
        self.repo_id = "mistralai/Mistral-7B-Instruct-v0.3" #tunable
        self.llm = HuggingFaceEndpoint( repo_id=self.repo_id, temperature= 0.2, top_k= 50, huggingfacehub_api_token=os.getenv('HUGGINGFACE_API_KEY') ) #tunable

        self.verbose = False #change this to see the explanations of how the LLM reached its conclusion

        #memory variables:
        self.memory_template = """You are a ambiguity clearer, your task is to examine the human question and check for any "he/she/it/they/them" ambiguities.
        return an updated human question fixing those ambiguities using the previous conversation context only.
        if there is not enought relevant context, RETURN HUMAN QUESTION AS IT IS
        YOUR ANSWER SHOULD BE A QUESTION WHICH ONLY CLARIFIES ANY AMBIGUITY IN human question by replacing it with their name
        RETURN IN FORMAT: New human question: (updated question)
        Previous conversation:
        {chat_history}

        human question: {question}
        New human question:
        """
        self.memory_prompt = PromptTemplate.from_template(self.memory_template)

        self.memory = ConversationBufferMemory(memory_key="chat_history")
        self.conversation = LLMChain(
            llm=self.llm,
            prompt=self.memory_prompt,
            verbose=False,
            memory=self.memory
        )
        #prompt variables
        self.Classifier_template = """
        You are a prompt classifier designed to classify questions from employees in an organization.
        classify the following question into "Relevant" or "Irrelevant", based on whether the query theme is of a question from an organization employee, the question could be about IT, HR, Finance or any other department
        Only answer from the specified classes and one word answers.

        Question: {question}
        Answer:
        """


        #Case 1:
        self.Employee_Template = """
          You are a highly knowledgeable and reflective chatbot designed to assist employees of an organization by answering their questions accurately and thoughtfully.
          Your goal is to provide well-reasoned and clear answers based on the provided context.

          Follow these steps to construct your response:
          1. **Understand the question**: Restate the question in simpler terms if necessary, ensuring you grasp the key aspects of what is being asked.
          2. **Analyze the context**: Examine the provided context and identify relevant information that applies to the question.
          3. **Evaluate implications**: Consider any potential rules, policies, or ethical considerations that could affect the answer.
          4. **Provide the answer**: Deliver a clear, concise, and actionable response based on your analysis.
          5. **Reflection**: Briefly explain your reasoning process to ensure transparency and to help the employee understand your conclusion.

          Examples:
          ---
          Context:
          "Employees are prohibited from accepting gifts valued over $50 from clients. If a gift exceeds this amount, it must be declined or reported to the ethics committee."

          Question:
          "One of Comerica's clients is hosting an open house that includes a raffle for some free airline tickets. If I win, can I accept the tickets?"

          Answer:
          1. **Understand the question**: Can the employee accept free airline tickets won in a raffle at a client's event?
          2. **Analyze the context**: The policy prohibits accepting gifts over $50. Airline tickets are likely valued well over this limit and would need to be reported or declined.
          3. **Evaluate implications**: Accepting the tickets could violate the company's ethics policy, even if won in a raffle, as they are provided by a client.
          4. **Provide the answer**: No, you should not accept the tickets without first consulting the ethics committee to determine whether an exception applies.
          5. **Reflection**: I based my answer on the explicit policy regarding gift value limits and the need to maintain ethical boundaries with clients.
          ---
          Context:
          "Employees are allowed to attend client-sponsored events, such as dinners or conferences, provided the primary purpose is business-related and attendance has been pre-approved by their manager."

          Question:
          "A client has invited me to a dinner event to discuss our ongoing project. Do I need approval to attend?"

          Answer:
          1. **Understand the question**: Does the employee need prior approval to attend a client dinner for business purposes?
          2. **Analyze the context**: The policy states that attendance at client events requires pre-approval from the employee’s manager.
          3. **Evaluate implications**: While the event seems business-related, attending without prior approval could breach company protocol.
          4. **Provide the answer**: Yes, you need to get approval from your manager before attending the dinner.
          5. **Reflection**: My answer aligns with the policy, ensuring adherence to company guidelines while allowing participation in legitimate business activities.
          ---
          Context: {context}
          Question: {question}
          Answer:
      """

        self.Augment_Prompt_Template = """
            The following are the file names available in our database:
            HR:
            - Code-of-conduct
            - Compensation-Benefits-Guide
            - Employee-appraisal-form
            - Employee-Handbook
            - Employee-Termination-Policy
            - Health-and-Safety-Guidelines
            - Onboarding-Manual
            - Remote-Work-Policy

            IT:
            - Cybersecurity-for-Employees
            - System-Access-Control-Policy
            - Technology-Devices-Policy

            Finance:
            - Expense-Report

            Given the following query:
            {question}

            You are tasked with identifying and returning the names of the **two most relevant files**, separated by "and," that are most helpful for addressing the query.
            do NOT provide reasoning or add any other text, just the names of files
            """



        self.Classifier_prompt = PromptTemplate( template=self.Classifier_template, input_variables=["question"] )
        self.Employee_prompt = PromptTemplate(template=self.Employee_Template, input_variables=["context", "question"] )
        self.get_relevant_docs_prompt = PromptTemplate( template=self.Augment_Prompt_Template, input_variables=["question"] )

        #chain variables
        self.classifier_chain = ({"question": RunnablePassthrough()} | self.Classifier_prompt | self.llm  | StrOutputParser() )
        self.get_relevant_docs_chain = ({"question": RunnablePassthrough()} | self.get_relevant_docs_prompt | self.llm  | StrOutputParser() )
        self.Employee_chain = ({"context": self.retriever | self.format_docs,  "question": RunnablePassthrough()} | self.Employee_prompt | self.llm | StrOutputParser() )
        self.full_chain = {"Relevancy": self.classifier_chain, "question": lambda x: x["question"]} | RunnableLambda(self.route)


    #this function will add the given filepath (as a string) to the pinecone vector db after parsing it
    def AddFileToDB(self, docs_to_load):
      # [ADD LOADING AND PARSING AND CHUNKING PART HERE]
      combined_text = ""
      for doc in docs_to_load:
        loader = PyMuPDFLoader(doc)
        documents = loader.load()
        # print(documents)
        for page in documents:
          text = page.page_content
          if "contents" in text.lower():
            continue
          text = re.sub(r'\bPage\s+\d+\b', '', text, flags=re.IGNORECASE)
          text = re.sub(r'\n', '', text).strip() #removing all newlines
          # print(text)
          text = re.sub(r'[^\w\s.,?!:;\'\"()&-]', '', text)
          combined_text += text + " "
      combined_text = combined_text.strip()
      # print(combined_text)
      text_splitter = TokenTextSplitter(chunk_size=self.CHUNK_SIZE, chunk_overlap=int(self.CHUNK_SIZE*self.CHUNK_OVERLAP))
      texts = text_splitter.split_text(combined_text)
      docs = text_splitter.create_documents(texts)
      print(docs)
      if self.index_name not in self.pc.list_indexes().names():
        self.pc.create_index(  #tunable
          name=self.index_name,
          dimension=768,
          metric="cosine",
          spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
          )
        )
      embeddings = HuggingFaceEmbeddings()
      index = self.pc.Index(self.index_name)
      vector_store = PineconeVectorStore(index=index, embedding=embeddings)
      uuids = [str(uuid4()) for _ in range(len(docs))]
      vector_store.add_documents(documents=docs, ids=uuids)


    # TODO: To be implemented
    def generate(self, query):
        # print(f"Generating with system prompt: {self.Employee_Template}")
        relevant_docs = self.get_relevant_docs(query)
        query = query + " try to answer from " + relevant_docs
        print(f"Augmented Query is: {query}")
        query_response = self.full_chain.invoke({"question": query})
        return query_response

    #Implement as per paper 1 with self generated text and break down of question into subsequent parts
    def Augment_prompt(self, query):
      pass


    # So this is what i had a theory about
    def get_relevant_docs(self,query):
        augmented_prompt = self.get_relevant_docs_chain.invoke({"question": query})
        documents = [
            "Code-of-conduct", "Compensation-Benefits-Guide", "Employee-appraisal-form",
            "Employee-Handbook", "Employee-Termination-Policy", "Health-and-Safety-Guidelines",
            "Onboarding-Manual", "Remote-Work-Policy", "Cybersecurity-for-Employees",
            "System-Access-Control-Policy", "Technology-Devices-Policy", "Expense-Report"
        ]
        words = augmented_prompt.split()
        matches = [doc for doc in documents if doc in words]
        return ", ".join(matches[:2])


    #Helper functions:
    def format_docs(self, docs):
        return "\n\n".join([d.page_content for d in docs])


    def route(self, info):
        if "relevant" in info["Relevancy"].lower():
          # print("Question was relevant")
          return self.Employee_chain.invoke(info["question"])
        else:
          return "Your question was not relevant to our organization"

# %%
# All eval questions:

#Init
bot = EmployeeChatBot()

#Question1
question = "One of Comerica's clients is hosting an open house that includes a raffle for some free airline tickets. If I win, can I accept the tickets?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question2
question = "At City of Fond du Lac, what is the list of holidays that i can be compensated as working atleast 20 hours per week?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question3
question = "What are the details i have to add in \“Employee Information\” section of the Employee Appraisal Form for the University of Texas, and what is the Rating Key they have provided?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question4
question = "As per the Recruitment section of the employee handbook, what is my reward if i someone is recruited from my referral in a hard-to-fill role?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question5
question = "What are my duties as a supervisor, before the start date, when onboarding new employees at the university of houston?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# <ipython-input-3-ff7b5bdbc89d>:35: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   self.memory = ConversationBufferMemory(memory_key="chat_history")
# <ipython-input-3-ff7b5bdbc89d>:36: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   self.conversation = LLMChain(
# Question is:
# One of Comerica's clients is hosting an open house that includes a raffle for some free airline tickets. If I win, can I accept the tickets?
# Augmented Query is: One of Comerica's clients is hosting an open house that includes a raffle for some free airline tickets. If I win, can I accept the tickets? try to answer from Remote-Work-Policy
#
# Answer is:
# 1. **Understand the question**: Can the employee accept free airline tickets won in a raffle at a client's event?
#       2. **Analyze the context**: The Remote Work Policy does not seem relevant to this question, as it pertains to remote work arrangements rather than accepting gifts from clients.
#       3. **Evaluate implications**: The Gift Prize Policy should be consulted instead, as it addresses the issue of accepting gifts from clients.
#       4. **Provide the answer**: No, you should not accept the tickets without first consulting the Gift Prize Policy to determine whether an exception applies.
#       5. **Reflection**: I based my answer on the understanding that the Remote Work Policy does not apply to this situation and that the Gift Prize Policy should be consulted for guidance on accepting gifts from clients.
# Question is:
# At City of Fond du Lac, what is the list of holidays that i can be compensated as working atleast 20 hours per week?
# Augmented Query is: At City of Fond du Lac, what is the list of holidays that i can be compensated as working atleast 20 hours per week? try to answer from Compensation-Benefits-Guide, Employee-Handbook
#
# Answer is:
# 1. **Understand the question**: What are the holidays that an employee working at least 20 hours per week can be compensated for at City of Fond du Lac?
#       2. **Analyze the context**: The provided context outlines the holidays for which employees are eligible for compensation, as well as the eligibility criteria.
#       3. **Evaluate implications**: Employees working at least 20 hours per week are eligible for compensation for the holidays listed in the context.
#       4. **Provide the answer**: The holidays for which an employee working at least 20 hours per week can be compensated at City of Fond du Lac are: New Years Day, Memorial Day, Independence Day, Labor Day, Thanksgiving Day, Christmas Eve (12 day), Christmas Day, and the Day after Thanksgiving.
#       5. **Reflection**: My answer is based on the provided context, which outlines the holiday schedule and eligibility criteria for employees working at least 20 hours per week.
# Question is:
# What are the details i have to add in \“Employee Information\” section of the Employee Appraisal Form for the University of Texas, and what is the Rating Key they have provided?
# Augmented Query is: What are the details i have to add in \“Employee Information\” section of the Employee Appraisal Form for the University of Texas, and what is the Rating Key they have provided? try to answer from Employee-Handbook
#
# Answer is:
# 1. **Understand the question**: The employee needs to fill out the "Employee Information" section of the University of Texas's Employee Appraisal Form, and they want to know what details to include and the rating key provided.
#       2. **Analyze the context**: The provided form includes sections for the employee's last name, first name, employee ID, position title, department, and whether they are a supervisor.
#       3. **Evaluate implications**: The employee should provide accurate and complete information to ensure proper evaluation and record-keeping.
#       4. **Provide the answer**: In the "Employee Information" section, the employee should include their last name, first name, employee ID, position title, department, and indicate whether they are a supervisor or not.
#       5. **Reflection**: I based my answer on the provided form, ensuring the employee understands the necessary information to complete the form accurately.
#       6. **Rating Key**: The rating key provided includes the following performance levels:
#           - EP - 5: Exceptional Performance
#           - PE - 4: Periodic Exceptional Performance
#           - SP - 3: Satisfactory Performance
#           - IP - 2: Inconsistent Performance
#
#           The key helps evaluate the employee's performance based on their job requirements and expectations.
# Question is:
# As per the Recruitment section of the employee handbook, what is my reward if i someone is recruited from my referral in a hard-to-fill role?
# Augmented Query is: As per the Recruitment section of the employee handbook, what is my reward if i someone is recruited from my referral in a hard-to-fill role? try to answer from Onboarding-Manual
#
# Answer is:
# 1. **Understand the question**: What is the reward for referring a candidate who gets hired in a hard-to-fill role?
#       2. **Analyze the context**: The context provides information about the employee referral rewards, including a higher bonus for hard-to-fill roles.
#       3. **Evaluate implications**: If the referred candidate is hired in a hard-to-fill role, the employee will receive a higher referral bonus.
#       4. **Provide the answer**: If you refer a candidate who gets hired in a hard-to-fill role, such as Data Scientist, you may receive a referral bonus of 6000.
#       5. **Reflection**: My answer is based on the information provided in the Recruitment section of the employee handbook, specifically the higher bonus for hard-to-fill roles.
# Question is:
# What are my duties as a supervisor, before the start date, when onboarding new employees at the university of houston?
# Augmented Query is: What are my duties as a supervisor, before the start date, when onboarding new employees at the university of houston? try to answer from Employee-Handbook
#
# Answer is:
# 1. **Understand the question**: What are the duties of a supervisor when onboarding new employees at the University of Houston, before the start date?
#       2. **Analyze the context**: The provided context includes an onboarding checklist and a page outlining UH policies. The checklist lists duties for both employees and supervisors, with the supervisor's duties including confirming the start date, sending a welcome email, and setting up the workspace. The UH policies page mentions benefits information, parking permits, and the first day's activities for managers.
#       3. **Evaluate implications**: As a supervisor, it is essential to ensure that the new employee's paperwork is complete, the workspace is set up, and the employee is informed about their role, department goals, and expectations.
#       4. **Provide the answer**: As a supervisor, your duties before the start date include confirming the start date, sending a welcome email, setting up the workspace, and providing position, department, and university information. On the first day, you should escort the new employee, introduce them to co-workers, provide keys, uniforms, equipment, and answer any immediate questions. You should also review the employee's role, department goals, and expectations, as well as provide training and schedule information.
#       5. **Reflection**: My answer is based on the onboarding checklist and UH policies, ensuring a smooth onboarding process for new employees and helping them adjust and become more productive quicker. Adhering to these guidelines will help the new employee feel like an important part of the team, leading to greater satisfaction from management and greater performance from the employee.

# %%
#Question6
question = "What are the productivity measures if i want to work remotely and are there any meetings i have to attend if i am working remotely?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question7
question = "While on the topic of cyber security, in what ways can i be exploited via Emails?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question8
question = "what are the user access control guidelines for system access control policy of the company?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question9
question = "What are the Unacceptable use scenarios of technology devices at workforce central?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question10
question = "how can i create expense report procurement card for Concur Travel and Expense System?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)
# Out:
# Question is:
# What are the productivity measures if i want to work remotely and are there any meetings i have to attend if i am working remotely?
# Augmented Query is: What are the productivity measures if i want to work remotely and are there any meetings i have to attend if i am working remotely? try to answer from Onboarding-Manual
#
# Answer is:
# 1. **Understand the question**: The employee wants to know about productivity measures and meetings if they work remotely.
#       2. **Analyze the context**: The policy states that remote employees are required to submit a Project Report weekly and attend the Friday All Staff meeting virtually.
#       3. **Evaluate implications**: Ensuring productivity and communication are key for remote employees, so regular reporting and virtual attendance at the All Staff meeting are important.
#       4. **Provide the answer**: To work remotely, you should submit a Project Report weekly and attend the Friday All Staff meeting virtually. These measures help maintain productivity and communication.
#       5. **Reflection**: My answer is based on the provided policy, emphasizing the importance of accountability and collaboration for remote employees.
# Question is:
# While on the topic of cyber security, in what ways can i be exploited via Emails?
# Augmented Query is: While on the topic of cyber security, in what ways can i be exploited via Emails? try to answer from Cybersecurity-for-Employees, System-Access-Control-Policy
#
# Answer is:
# 1. **Understand the question**: The employee is asking about potential cybersecurity risks related to emails.
#       2. **Analyze the context**: The provided context includes policies on email use and acceptable use of technology resources.
#       3. **Evaluate implications**: Emails can be a common vector for cyber attacks, such as phishing, malware, and spam.
#       4. **Provide the answer**: Emails can be exploited through phishing attacks, which aim to acquire sensitive information by masquerading as a trustworthy entity. Common phishing techniques include embedding links to unsecured websites, installing Trojans via malicious email attachments, and spoofing the sender address.
#       5. **Reflection**: I based my answer on the provided context, focusing on the most common email threats employees should be aware of to maintain cybersecurity.
# Question is:
# what are the user access control guidelines for system access control policy of the company?
# Augmented Query is: what are the user access control guidelines for system access control policy of the company? try to answer from System-Access-Control-Policy
#
# Answer is:
# 1. **Understand the question**: What are the guidelines for user access control in the company's system access control policy?
#       2. **Analyze the context**: The policy outlines various aspects of user access control, including user account creation, access right reviews, and revocation procedures.
#       3. **Evaluate implications**: The policy emphasizes the importance of limiting access to only authorized users, following the "Least Privilege" principle, and segregating duties to prevent unauthorized access.
#       4. **Provide the answer**: The guidelines for user access control in the company's system access control policy include:
#           - Requests for access must be reviewed and approved according to ISMS-PC-01 User Access Request Procedure.
#           - Only authorized users have access to the company's information systems, and access rights must be restricted to the appropriate level according to work responsibilities.
#           - User accounts must have their own user account and must use that account throughout their tenure with the company.
#           - User access rights must be reviewed at least once a year, with more frequent reviews for users with special privileges or remote access rights.
#           - User system access rights must be reviewed whenever there are changes in the user's employment status.
#           - All system access rights must be revoked immediately when a user no longer requires access to the system.
#           - Supervisors must promptly inform the system administrator when individuals under their supervision no longer require access to the company's information systems and equipment.
#           - The policy is reviewed and updated at least once a year to ensure its content remains complete, effective, and appropriate.
#           - Any breach, violation, negligence, or non-compliance with the policy may result in penalties at the company's discretion or disciplinary action.
#       5. **Reflection**: My answer is based on the provided system access control policy, which outlines guidelines for user access control to ensure the protection of data and information systems while maintaining appropriate access for authorized users.
# Question is:
# What are the Unacceptable use scenarios of technology devices at workforce central?
# Augmented Query is: What are the Unacceptable use scenarios of technology devices at workforce central? try to answer from Cybersecurity-for-Employees
#
# Answer is:
# 1. **Understand the question**: What activities are prohibited when using technology devices at WorkForce Central from a cybersecurity perspective?
#       2. **Analyze the context**: The policy outlines various activities that are considered unacceptable use of technology devices at WorkForce Central.
#       3. **Evaluate implications**: Engaging in these activities can lead to risks such as virus attacks, compromise of network systems and services, compliance concerns, and potential legal issues.
#       4. **Provide the answer**: The following activities are strictly prohibited:
#           - Violations of the rights of any person or company protected by copyright, trade secret, patent, or other intellectual property laws.
#           - Unauthorized access, use, or disclosure of another person's account, password, or other security information.
#           - Unauthorized access, use, or disclosure of WorkForce Central's confidential or proprietary information.
#           - Attempting to interfere with, disrupt, or deny service to any network, server, or other technology device.
#           - Installing, using, or distributing unauthorized software or applications.
#           - Using technology devices for personal financial gain, such as mining cryptocurrencies.
#           - Using technology devices for illegal activities, such as hacking, phishing, or spamming.
#           - Sharing or storing inappropriate content, such as pornography or hate speech.
#           - Using technology devices to engage in activities that are harassing, threatening, or discriminatory.
#           - Using technology devices to engage in activities that are not job-related or that interfere with work responsibilities.
#       5. **Reflection**: My answer is based on the provided policy, which outlines various activities that are considered unacceptable use of technology devices at WorkForce Central from a cybersecurity perspective. It is essential to maintain the security and integrity of the network and systems while adhering to legal and ethical guidelines.
# Question is:
# how can i create expense report procurement card for Concur Travel and Expense System?
# Augmented Query is: how can i create expense report procurement card for Concur Travel and Expense System? try to answer from
#
# Answer is:
# 1. **Understand the question**: The user wants to know how to create a Procurement Card expense report in the Concur Travel & Expense System.
#       2. **Analyze the context**: The provided context outlines the steps for creating a Procurement Card expense report in Concur.
#       3. **Evaluate implications**: The user needs to follow the provided steps to successfully create the expense report.
#       4. **Provide the answer**: To create a Procurement Card expense report in the Concur Travel & Expense System, access the system via your campus portal, locate the CU Resources section, and select the Concur Travel & Expense System link. From the Active Work section of your Concur home page, click the New Expense Report tab. On the Report Header page, use the Policy dropdown and select Procurement Card. Follow the remaining steps as outlined in the provided context.
#       5. **Reflection**: My answer is based on the provided context, which outlines the step-by-step process for creating a Procurement Card expense report in Concur. I have summarized the key steps for the user to follow.

# %% [markdown]
# # High Temperature: (1)

# %%
class EmployeeChatBot:
    # TODO: To be implemented
    def __init__(self):
        #loading variables:
        self.combined_text = ""
        self.CHUNK_SIZE = 256
        self.CHUNK_OVERLAP = 0.50
        #storing variables:
        self.pc = Pinecone(api_key=os.environ.get("PINECONE_API_KEY"))
        self.index_name = "employee-queries-db" #keep the name small
        self.embeddings = HuggingFaceEmbeddings()
        self.index = self.pc.Index(self.index_name) #Remember, i can do this because i have already once created this index, else create index first
        self.vector_store = PineconeVectorStore(index=self.index, embedding=self.embeddings)
        # generating variables
        self.retriever = self.vector_store.as_retriever( search_type="similarity_score_threshold", search_kwargs={"k": 3, "score_threshold": 0.5},) #tunable
        self.repo_id = "mistralai/Mistral-7B-Instruct-v0.3" #tunable
        self.llm = HuggingFaceEndpoint( repo_id=self.repo_id, temperature= 1, top_k= 50, huggingfacehub_api_token=os.getenv('HUGGINGFACE_API_KEY') ) #tunable

        self.verbose = False #change this to see the explanations of how the LLM reached its conclusion

        #memory variables:
        self.memory_template = """You are a ambiguity clearer, your task is to examine the human question and check for any "he/she/it/they/them" ambiguities.
        return an updated human question fixing those ambiguities using the previous conversation context only.
        if there is not enought relevant context, RETURN HUMAN QUESTION AS IT IS
        YOUR ANSWER SHOULD BE A QUESTION WHICH ONLY CLARIFIES ANY AMBIGUITY IN human question by replacing it with their name
        RETURN IN FORMAT: New human question: (updated question)
        Previous conversation:
        {chat_history}

        human question: {question}
        New human question:
        """
        self.memory_prompt = PromptTemplate.from_template(self.memory_template)

        self.memory = ConversationBufferMemory(memory_key="chat_history")
        self.conversation = LLMChain(
            llm=self.llm,
            prompt=self.memory_prompt,
            verbose=False,
            memory=self.memory
        )
        #prompt variables
        self.Classifier_template = """
        You are a prompt classifier designed to classify questions from employees in an organization.
        classify the following question into "Relevant" or "Irrelevant", based on whether the query theme is of a question from an organization employee, the question could be about IT, HR, Finance or any other department
        Only answer from the specified classes and one word answers.

        Question: {question}
        Answer:
        """


        #Case 1:
        self.Employee_Template = """
          You are a highly knowledgeable and reflective chatbot designed to assist employees of an organization by answering their questions accurately and thoughtfully.
          Your goal is to provide well-reasoned and clear answers based on the provided context.

          Follow these steps to construct your response:
          1. **Understand the question**: Restate the question in simpler terms if necessary, ensuring you grasp the key aspects of what is being asked.
          2. **Analyze the context**: Examine the provided context and identify relevant information that applies to the question.
          3. **Evaluate implications**: Consider any potential rules, policies, or ethical considerations that could affect the answer.
          4. **Provide the answer**: Deliver a clear, concise, and actionable response based on your analysis.
          5. **Reflection**: Briefly explain your reasoning process to ensure transparency and to help the employee understand your conclusion.

          Examples:
          ---
          Context:
          "Employees are prohibited from accepting gifts valued over $50 from clients. If a gift exceeds this amount, it must be declined or reported to the ethics committee."

          Question:
          "One of Comerica's clients is hosting an open house that includes a raffle for some free airline tickets. If I win, can I accept the tickets?"

          Answer:
          1. **Understand the question**: Can the employee accept free airline tickets won in a raffle at a client's event?
          2. **Analyze the context**: The policy prohibits accepting gifts over $50. Airline tickets are likely valued well over this limit and would need to be reported or declined.
          3. **Evaluate implications**: Accepting the tickets could violate the company's ethics policy, even if won in a raffle, as they are provided by a client.
          4. **Provide the answer**: No, you should not accept the tickets without first consulting the ethics committee to determine whether an exception applies.
          5. **Reflection**: I based my answer on the explicit policy regarding gift value limits and the need to maintain ethical boundaries with clients.
          ---
          Context:
          "Employees are allowed to attend client-sponsored events, such as dinners or conferences, provided the primary purpose is business-related and attendance has been pre-approved by their manager."

          Question:
          "A client has invited me to a dinner event to discuss our ongoing project. Do I need approval to attend?"

          Answer:
          1. **Understand the question**: Does the employee need prior approval to attend a client dinner for business purposes?
          2. **Analyze the context**: The policy states that attendance at client events requires pre-approval from the employee’s manager.
          3. **Evaluate implications**: While the event seems business-related, attending without prior approval could breach company protocol.
          4. **Provide the answer**: Yes, you need to get approval from your manager before attending the dinner.
          5. **Reflection**: My answer aligns with the policy, ensuring adherence to company guidelines while allowing participation in legitimate business activities.
          ---
          Context: {context}
          Question: {question}
          Answer:
      """

        self.Augment_Prompt_Template = """
            The following are the file names available in our database:
            HR:
            - Code-of-conduct
            - Compensation-Benefits-Guide
            - Employee-appraisal-form
            - Employee-Handbook
            - Employee-Termination-Policy
            - Health-and-Safety-Guidelines
            - Onboarding-Manual
            - Remote-Work-Policy

            IT:
            - Cybersecurity-for-Employees
            - System-Access-Control-Policy
            - Technology-Devices-Policy

            Finance:
            - Expense-Report

            Given the following query:
            {question}

            You are tasked with identifying and returning the names of the **two most relevant files**, separated by "and," that are most helpful for addressing the query.
            do NOT provide reasoning or add any other text, just the names of files
            """



        self.Classifier_prompt = PromptTemplate( template=self.Classifier_template, input_variables=["question"] )
        self.Employee_prompt = PromptTemplate(template=self.Employee_Template, input_variables=["context", "question"] )
        self.get_relevant_docs_prompt = PromptTemplate( template=self.Augment_Prompt_Template, input_variables=["question"] )

        #chain variables
        self.classifier_chain = ({"question": RunnablePassthrough()} | self.Classifier_prompt | self.llm  | StrOutputParser() )
        self.get_relevant_docs_chain = ({"question": RunnablePassthrough()} | self.get_relevant_docs_prompt | self.llm  | StrOutputParser() )
        self.Employee_chain = ({"context": self.retriever | self.format_docs,  "question": RunnablePassthrough()} | self.Employee_prompt | self.llm | StrOutputParser() )
        self.full_chain = {"Relevancy": self.classifier_chain, "question": lambda x: x["question"]} | RunnableLambda(self.route)


    #this function will add the given filepath (as a string) to the pinecone vector db after parsing it
    def AddFileToDB(self, docs_to_load):
      # [ADD LOADING AND PARSING AND CHUNKING PART HERE]
      combined_text = ""
      for doc in docs_to_load:
        loader = PyMuPDFLoader(doc)
        documents = loader.load()
        # print(documents)
        for page in documents:
          text = page.page_content
          if "contents" in text.lower():
            continue
          text = re.sub(r'\bPage\s+\d+\b', '', text, flags=re.IGNORECASE)
          text = re.sub(r'\n', '', text).strip() #removing all newlines
          # print(text)
          text = re.sub(r'[^\w\s.,?!:;\'\"()&-]', '', text)
          combined_text += text + " "
      combined_text = combined_text.strip()
      # print(combined_text)
      text_splitter = TokenTextSplitter(chunk_size=self.CHUNK_SIZE, chunk_overlap=int(self.CHUNK_SIZE*self.CHUNK_OVERLAP))
      texts = text_splitter.split_text(combined_text)
      docs = text_splitter.create_documents(texts)
      print(docs)
      if self.index_name not in self.pc.list_indexes().names():
        self.pc.create_index(  #tunable
          name=self.index_name,
          dimension=768,
          metric="cosine",
          spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
          )
        )
      embeddings = HuggingFaceEmbeddings()
      index = self.pc.Index(self.index_name)
      vector_store = PineconeVectorStore(index=index, embedding=embeddings)
      uuids = [str(uuid4()) for _ in range(len(docs))]
      vector_store.add_documents(documents=docs, ids=uuids)


    # TODO: To be implemented
    def generate(self, query):
        # print(f"Generating with system prompt: {self.Employee_Template}")
        relevant_docs = self.get_relevant_docs(query)
        query = query + " try to answer from " + relevant_docs
        print(f"Augmented Query is: {query}")
        query_response = self.full_chain.invoke({"question": query})
        return query_response

    #Implement as per paper 1 with self generated text and break down of question into subsequent parts
    def Augment_prompt(self, query):
      pass


    # So this is what i had a theory about
    def get_relevant_docs(self,query):
        augmented_prompt = self.get_relevant_docs_chain.invoke({"question": query})
        documents = [
            "Code-of-conduct", "Compensation-Benefits-Guide", "Employee-appraisal-form",
            "Employee-Handbook", "Employee-Termination-Policy", "Health-and-Safety-Guidelines",
            "Onboarding-Manual", "Remote-Work-Policy", "Cybersecurity-for-Employees",
            "System-Access-Control-Policy", "Technology-Devices-Policy", "Expense-Report"
        ]
        words = augmented_prompt.split()
        matches = [doc for doc in documents if doc in words]
        return ", ".join(matches[:2])


    #Helper functions:
    def format_docs(self, docs):
        return "\n\n".join([d.page_content for d in docs])


    def route(self, info):
        if "relevant" in info["Relevancy"].lower():
          # print("Question was relevant")
          return self.Employee_chain.invoke(info["question"])
        else:
          return "Your question was not relevant to our organization"

# %%
# All eval questions:

#Init
bot = EmployeeChatBot()

#Question1
question = "One of Comerica's clients is hosting an open house that includes a raffle for some free airline tickets. If I win, can I accept the tickets?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question2
question = "At City of Fond du Lac, what is the list of holidays that i can be compensated as working atleast 20 hours per week?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question3
question = "What are the details i have to add in \“Employee Information\” section of the Employee Appraisal Form for the University of Texas, and what is the Rating Key they have provided?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question4
question = "As per the Recruitment section of the employee handbook, what is my reward if i someone is recruited from my referral in a hard-to-fill role?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question5
question = "What are my duties as a supervisor, before the start date, when onboarding new employees at the university of houston?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)
# Out:
# Question is:
# One of Comerica's clients is hosting an open house that includes a raffle for some free airline tickets. If I win, can I accept the tickets?
# Augmented Query is: One of Comerica's clients is hosting an open house that includes a raffle for some free airline tickets. If I win, can I accept the tickets? try to answer from Remote-Work-Policy
#
# Answer is:
# 1. **Understand the question**: Can the employee accept free airline tickets won in a raffle at a client's event if the policy being referred to is the Remote-Work Policy?
#       2. **Analyze the context**: The Remote-Work Policy does not provide guidance on gift acceptance from clients. Therefore, the Gift-Prize Policy should be consulted to answer this question.
#       3. **Evaluate implications**: Since the Gift-Prize Policy states that employees should not accept gift-prizes from clients, it is likely that the same rule applies even though the Remote-Work Policy does not specifically mention it.
#       4. **Provide the answer**: No, the employee should not accept the tickets without consulting the Gift-Prize Policy or speaking with the HR department to determine whether an exception applies.
#       5. **Reflection**: I based my answer on the Gift-Prize Policy, as the Remote-Work Policy does not provide guidance on this topic and maintaining ethical boundaries with clients is essential in any context.
# Question is:
# At City of Fond du Lac, what is the list of holidays that i can be compensated as working atleast 20 hours per week?
# Augmented Query is: At City of Fond du Lac, what is the list of holidays that i can be compensated as working atleast 20 hours per week? try to answer from Compensation-Benefits-Guide, Employee-Handbook
#
# Answer is:
# 1. **Understand the question**: What is the list of holidays that an employee working at least 20 hours per week can be compensated for at City of Fond du Lac?
#       2. **Analyze the context**: The context provides a list of holidays and compensation conditions for employees working at least 20 hours per week.
#       3. **Evaluate implications**: The provided list of holidays appears to be complete, assuming the employee works at least 20 hours per week and the holidays fall within the given year.
#       4. **Provide the answer**: The employee can be compensated for the following holidays: New Years Day, Memorial Day, Independence Day, Labor Day, Thanksgiving Day, Christmas Eve (12-day), Christmas Day, and Day after Thanksgiving.
#       5. **Reflection**: My answer is based on the provided list of holidays, with the caveat that the employee works at least 20 hours per week and the holidays fall within the given year. I did not consider other factors, such as whether the employee is a seasonal, temporary, or limited-term employee, as these groups are not eligible for holiday compensation.
# Question is:
# What are the details i have to add in \“Employee Information\” section of the Employee Appraisal Form for the University of Texas, and what is the Rating Key they have provided?
# Augmented Query is: What are the details i have to add in \“Employee Information\” section of the Employee Appraisal Form for the University of Texas, and what is the Rating Key they have provided? try to answer from Onboarding-Manual
#
# Answer is:
# 1. **Understand the question**: You need to fill out the Employee Information section of the University of Texas's Employee Appraisal Form, and I'm asked to explain the Rating Key they've provided.
#       2. **Analyze the context**: The provided information includes a blank Employee Appraisal Form and a Rating Key, which is a scale for evaluating job performance.
#       3. **Evaluate implications**: It's crucial to accurately complete the form, including filling out the employee's details and providing appropriate performance ratings based on the Rating Key.
#       4. **Provide the answer**: In the Employee Information section, you should fill out the Last Name, First Name, Employee ID, Position Title, Department, and indicate whether the employee is a supervisor (Yes or No). The Rating Key includes four performance levels, ranging from Exceptional (EP - 5) to Inconsistent Performance (IP - 2).
#       5. **Reflection**: I based my answer on the provided context, ensuring you understand the components of the Employee Appraisal Form and the Rating Key, enabling you to accurately complete the form.
# Question is:
# As per the Recruitment section of the employee handbook, what is my reward if i someone is recruited from my referral in a hard-to-fill role?
# Augmented Query is: As per the Recruitment section of the employee handbook, what is my reward if i someone is recruited from my referral in a hard-to-fill role? try to answer from Employee-Handbook
#
# Answer is:
# 1. **Understand the question**: The question asks about the employee's reward for referring a candidate who gets hired in a hard-to-fill role.
#       2. **Analyze the context**: The context mentions referral rewards and states that they can be higher for hard-to-fill roles such as Data Scientist.
#       3. **Evaluate implications**: If the referred candidate lands a hard-to-fill role, the employee can receive a higher reward.
#       4. **Provide the answer**: If you refer a candidate who gets hired for a hard-to-fill role such as Data Scientist, you can receive a referral bonus of 6000.
#       5. **Reflection**: I based my answer on the provided context regarding referral rewards and the explicit mention of higher bonuses for hard-to-fill roles like Data Scientist.
# Question is:
# What are my duties as a supervisor, before the start date, when onboarding new employees at the university of houston?
# Augmented Query is: What are my duties as a supervisor, before the start date, when onboarding new employees at the university of houston? try to answer from Employee-Handbook, Onboarding-Manual
#
# Answer is:
# 1. **Understand the question**: As a supervisor, what tasks should I complete before the start date to ensure a successful onboarding process for new employees at the University of Houston?
#       2. **Analyze the context**: From the provided context, it appears that the university has an onboarding manual, which contains a checklist of duties for both employees and supervisors.
#       3. **Evaluate implications**: Completing these tasks will help ensure a smooth onboarding process, improving employee satisfaction, retention, and productivity.
#       4. **Provide the answer**: As a supervisor, you should confirm the start date, assure background checks and other paperwork have been completed, and send a welcome email with relevant information, such as when and where to report, what to wear, and expectations for the first day. Additionally, set up the workspace, contact IT for computer and phone setup, and establish regular communication.
#       5. **Reflection**: My answer is based on the provided onboarding manual, focusing on tasks that supervisors should complete before the start date to help new employees adjust and become productive more quickly. Ensuring these tasks are accomplished also supports the university's goals of improved employee satisfaction, retention, and performance.

# %%
#Question6
question = "What are the productivity measures if i want to work remotely and are there any meetings i have to attend if i am working remotely?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question7
question = "While on the topic of cyber security, in what ways can i be exploited via Emails?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question8
question = "what are the user access control guidelines for system access control policy of the company?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question9
question = "What are the Unacceptable use scenarios of technology devices at workforce central?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question10
question = "how can i create expense report procurement card for Concur Travel and Expense System?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)
# Out:
# Question is:
# What are the productivity measures if i want to work remotely and are there any meetings i have to attend if i am working remotely?
# Augmented Query is: What are the productivity measures if i want to work remotely and are there any meetings i have to attend if i am working remotely? try to answer from Onboarding-Manual, Remote-Work-Policy
#
# Answer is:
# 1. **Understand the question**: What are the productivity measures and meeting requirements if an employee wishes to work remotely?
#       2. **Analyze the context**: The provided policies detail productivity measures and meeting requirements for remote employees.
#       3. **Evaluate implications**: Understanding these requirements will help the employee maintain productivity and collaborate effectively while working remotely.
#       4. **Provide the answer**: To work remotely, you should follow the guidelines outlined in the Remote Working Policy. This includes using secure and fast internet connections, minimizing distractions, checking in with your team frequently, and submitting a weekly project report. Additionally, employees must attend meetings as required, with some exceptions such as the CEO meeting and the All Staff meeting where taking comp time is not allowed.
#       5. **Reflection**: I based my answer on the provided context, focusing on the requirements for remote work and meeting attendance to ensure a productive and collaborative remote work environment.
# Question is:
# While on the topic of cyber security, in what ways can i be exploited via Emails?
# Augmented Query is: While on the topic of cyber security, in what ways can i be exploited via Emails? try to answer from Cybersecurity-for-Employees, System-Access-Control-Policy
#
# Answer is:
# 1. Understand the question: The employee wants to know about potential email-based threats to cyber security.
#       2. Analyze the context: The provided policy mentions email phishing as a major concern, along with unsolicited emails and spamming.
#       3. Evaluate implications: Email phishing, spamming, and sending unsolicited emails can lead to information theft, network intrusion, and data loss, potentially causing significant harm to both individuals and the company.
#       4. Provide the answer: The employee should be aware of email phishing, where cybercriminals try to obtain sensitive information by pretending to be a trusted entity. Some common phishing techniques include redirecting users to unsecured websites, installing Trojans, and spoofing sender addresses.
#       5. Reflection: My answer focuses on email-based threats to cyber security, specifically addressing email phishing as the primary concern in the provided policy and discussing common phishing techniques to help the employee better understand the issue.
# Question is:
# what are the user access control guidelines for system access control policy of the company?
# Augmented Query is: what are the user access control guidelines for system access control policy of the company? try to answer from Cybersecurity-for-Employees, System-Access-Control-Policy
#
# Answer is:
# 1. Understand the question: What are the guidelines for user access control in the Company's system access control policy?
#       2. Analyze the context: The policy emphasizes controlling access to the Company's information systems and services, approving requests, and limiting access rights to the appropriate level based on job responsibilities. It also mentions reviewing access rights regularly and segregating duties to prevent unauthorized access. External access by service providers or partners requires review and approval, compliance with policies, and limiting access to designated hosts or servers.
#       3. Evaluate implications: User access control guidelines are essential to maintaining data accuracy, integrity, and security, as well as ensuring appropriate user access based on job responsibilities. Reviewing access rights regularly and segregating duties help to prevent unauthorized access and potential data breaches.
#       4. Provide the answer: Guidelines for user access control in the Company's system access control policy include reviewing access requests according to established procedures, granting access only as necessary, and limiting access rights based on job responsibilities. Regular reviews of access rights are necessary, as well as segregation of duties to prevent any individual from accessing systems beyond their job responsibilities. External service providers or partners must comply with the Company's information technology security policies and agree to access only the designated hosts or servers.
#       5. Reflection: I based my answer on the explicit policy regarding user access control, emphasizing the need for appropriate access controls, regular reviews, and segregation of duties to ensure the security of the Company's information systems and data.
# Question is:
# What are the Unacceptable use scenarios of technology devices at workforce central?
# Augmented Query is: What are the Unacceptable use scenarios of technology devices at workforce central? try to answer from Cybersecurity-for-Employees
#
# Answer is:
# 1. **Understand the question**: The question seeks to identify the unacceptable uses of technology devices at WorkForce Central from a cybersecurity perspective.
#       2. **Analyze the context**: The provided policy outlines several unacceptable activities that employees are not allowed to engage in while utilizing WorkForce Central-owned resources.
#       3. **Evaluate implications**: Engaging in unacceptable activities can result in risks such as virus attacks, compromise of network systems and services, compliance concerns, and potential legal issues.
#       4. **Provide the answer**: The policy prohibits the following activities, with no exceptions:
#          - Violations of the rights of any person or company protected by copyright, trade secret, patent, or trademark laws
#          - Unauthorized access or attempts to access the accounts of other users or unauthorized access to other computers or computer systems
#          - Attempting to access, download, distribute, or store unlawful material or content, such as offensive or obscene images or messages
#          - Unauthorized use, disclosure, or distribution of another person’s personal or private information
#          - Unauthorized access or use of the company's network or systems for personal gain or non-business purposes
#          - Engaging in activities that disrupt the normal operation of the company's network or systems
#       5. **Reflection**: My answer is based on the specific policy provided, focusing on the unacceptable activities to ensure cybersecurity and compliance within the organization.
# Question is:
# how can i create expense report procurement card for Concur Travel and Expense System?
# Augmented Query is: how can i create expense report procurement card for Concur Travel and Expense System? try to answer from
#
# Answer is:
# 1. **Understand the question**: The user wants to create an expense report for the Procurement Card in Concur Travel and Expense System.
#       2. **Analyze the context**: The user needs to access Concur via their campus portal, select the Procurement Card expense report, and fill out the Report Header page.
#       3. **Evaluate implications**: The user must be a legitimate employee with appropriate authorization to create expense reports.
#       4. **Provide the answer**: To create an expense report for the Procurement Card in Concur Travel and Expense System, follow these steps:
#        - Access Concur via your campus portal.
#        - Locate your CU Resources section and, under the Business Applications area, select the Concur Travel & Expense System link.
#        - From the Active Work section of your Concur home page, click the New Expense Report tab.
#        - On the Report Header page, use the Policy dropdown and select Procurement Card.
#        - Fill out the required information in the Report Header, such as report name, comments (if necessary), and alternate contact employee (if necessary).
#       5. **Reflection**: I based my answer on the provided context and step-by-step guide for creating a Procurement Card expense report in Concur Travel and Expense System.

# %% [markdown]
# # Very High Temperature: (5)

# %%
class EmployeeChatBot:
    # TODO: To be implemented
    def __init__(self):
        #loading variables:
        self.combined_text = ""
        self.CHUNK_SIZE = 256
        self.CHUNK_OVERLAP = 0.50
        #storing variables:
        self.pc = Pinecone(api_key=os.environ.get("PINECONE_API_KEY"))
        self.index_name = "employee-queries-db" #keep the name small
        self.embeddings = HuggingFaceEmbeddings()
        self.index = self.pc.Index(self.index_name) #Remember, i can do this because i have already once created this index, else create index first
        self.vector_store = PineconeVectorStore(index=self.index, embedding=self.embeddings)
        # generating variables
        self.retriever = self.vector_store.as_retriever( search_type="similarity_score_threshold", search_kwargs={"k": 3, "score_threshold": 0.5},) #tunable
        self.repo_id = "mistralai/Mistral-7B-Instruct-v0.3" #tunable
        self.llm = HuggingFaceEndpoint( repo_id=self.repo_id, temperature= 2, top_k= 50, huggingfacehub_api_token=os.getenv('HUGGINGFACE_API_KEY') ) #tunable

        self.verbose = False #change this to see the explanations of how the LLM reached its conclusion

        #memory variables:
        self.memory_template = """You are a ambiguity clearer, your task is to examine the human question and check for any "he/she/it/they/them" ambiguities.
        return an updated human question fixing those ambiguities using the previous conversation context only.
        if there is not enought relevant context, RETURN HUMAN QUESTION AS IT IS
        YOUR ANSWER SHOULD BE A QUESTION WHICH ONLY CLARIFIES ANY AMBIGUITY IN human question by replacing it with their name
        RETURN IN FORMAT: New human question: (updated question)
        Previous conversation:
        {chat_history}

        human question: {question}
        New human question:
        """
        self.memory_prompt = PromptTemplate.from_template(self.memory_template)

        self.memory = ConversationBufferMemory(memory_key="chat_history")
        self.conversation = LLMChain(
            llm=self.llm,
            prompt=self.memory_prompt,
            verbose=False,
            memory=self.memory
        )
        #prompt variables
        self.Classifier_template = """
        You are a prompt classifier designed to classify questions from employees in an organization.
        classify the following question into "Relevant" or "Irrelevant", based on whether the query theme is of a question from an organization employee, the question could be about IT, HR, Finance or any other department
        Only answer from the specified classes and one word answers.

        Question: {question}
        Answer:
        """


        #Case 1:
        self.Employee_Template = """
          You are a highly knowledgeable and reflective chatbot designed to assist employees of an organization by answering their questions accurately and thoughtfully.
          Your goal is to provide well-reasoned and clear answers based on the provided context.

          Follow these steps to construct your response:
          1. **Understand the question**: Restate the question in simpler terms if necessary, ensuring you grasp the key aspects of what is being asked.
          2. **Analyze the context**: Examine the provided context and identify relevant information that applies to the question.
          3. **Evaluate implications**: Consider any potential rules, policies, or ethical considerations that could affect the answer.
          4. **Provide the answer**: Deliver a clear, concise, and actionable response based on your analysis.
          5. **Reflection**: Briefly explain your reasoning process to ensure transparency and to help the employee understand your conclusion.

          Examples:
          ---
          Context:
          "Employees are prohibited from accepting gifts valued over $50 from clients. If a gift exceeds this amount, it must be declined or reported to the ethics committee."

          Question:
          "One of Comerica's clients is hosting an open house that includes a raffle for some free airline tickets. If I win, can I accept the tickets?"

          Answer:
          1. **Understand the question**: Can the employee accept free airline tickets won in a raffle at a client's event?
          2. **Analyze the context**: The policy prohibits accepting gifts over $50. Airline tickets are likely valued well over this limit and would need to be reported or declined.
          3. **Evaluate implications**: Accepting the tickets could violate the company's ethics policy, even if won in a raffle, as they are provided by a client.
          4. **Provide the answer**: No, you should not accept the tickets without first consulting the ethics committee to determine whether an exception applies.
          5. **Reflection**: I based my answer on the explicit policy regarding gift value limits and the need to maintain ethical boundaries with clients.
          ---
          Context:
          "Employees are allowed to attend client-sponsored events, such as dinners or conferences, provided the primary purpose is business-related and attendance has been pre-approved by their manager."

          Question:
          "A client has invited me to a dinner event to discuss our ongoing project. Do I need approval to attend?"

          Answer:
          1. **Understand the question**: Does the employee need prior approval to attend a client dinner for business purposes?
          2. **Analyze the context**: The policy states that attendance at client events requires pre-approval from the employee’s manager.
          3. **Evaluate implications**: While the event seems business-related, attending without prior approval could breach company protocol.
          4. **Provide the answer**: Yes, you need to get approval from your manager before attending the dinner.
          5. **Reflection**: My answer aligns with the policy, ensuring adherence to company guidelines while allowing participation in legitimate business activities.
          ---
          Context: {context}
          Question: {question}
          Answer:
      """

        self.Augment_Prompt_Template = """
            The following are the file names available in our database:
            HR:
            - Code-of-conduct
            - Compensation-Benefits-Guide
            - Employee-appraisal-form
            - Employee-Handbook
            - Employee-Termination-Policy
            - Health-and-Safety-Guidelines
            - Onboarding-Manual
            - Remote-Work-Policy

            IT:
            - Cybersecurity-for-Employees
            - System-Access-Control-Policy
            - Technology-Devices-Policy

            Finance:
            - Expense-Report

            Given the following query:
            {question}

            You are tasked with identifying and returning the names of the **two most relevant files**, separated by "and," that are most helpful for addressing the query.
            do NOT provide reasoning or add any other text, just the names of files
            """



        self.Classifier_prompt = PromptTemplate( template=self.Classifier_template, input_variables=["question"] )
        self.Employee_prompt = PromptTemplate(template=self.Employee_Template, input_variables=["context", "question"] )
        self.get_relevant_docs_prompt = PromptTemplate( template=self.Augment_Prompt_Template, input_variables=["question"] )

        #chain variables
        self.classifier_chain = ({"question": RunnablePassthrough()} | self.Classifier_prompt | self.llm  | StrOutputParser() )
        self.get_relevant_docs_chain = ({"question": RunnablePassthrough()} | self.get_relevant_docs_prompt | self.llm  | StrOutputParser() )
        self.Employee_chain = ({"context": self.retriever | self.format_docs,  "question": RunnablePassthrough()} | self.Employee_prompt | self.llm | StrOutputParser() )
        self.full_chain = {"Relevancy": self.classifier_chain, "question": lambda x: x["question"]} | RunnableLambda(self.route)


    #this function will add the given filepath (as a string) to the pinecone vector db after parsing it
    def AddFileToDB(self, docs_to_load):
      # [ADD LOADING AND PARSING AND CHUNKING PART HERE]
      combined_text = ""
      for doc in docs_to_load:
        loader = PyMuPDFLoader(doc)
        documents = loader.load()
        # print(documents)
        for page in documents:
          text = page.page_content
          if "contents" in text.lower():
            continue
          text = re.sub(r'\bPage\s+\d+\b', '', text, flags=re.IGNORECASE)
          text = re.sub(r'\n', '', text).strip() #removing all newlines
          # print(text)
          text = re.sub(r'[^\w\s.,?!:;\'\"()&-]', '', text)
          combined_text += text + " "
      combined_text = combined_text.strip()
      # print(combined_text)
      text_splitter = TokenTextSplitter(chunk_size=self.CHUNK_SIZE, chunk_overlap=int(self.CHUNK_SIZE*self.CHUNK_OVERLAP))
      texts = text_splitter.split_text(combined_text)
      docs = text_splitter.create_documents(texts)
      print(docs)
      if self.index_name not in self.pc.list_indexes().names():
        self.pc.create_index(  #tunable
          name=self.index_name,
          dimension=768,
          metric="cosine",
          spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
          )
        )
      embeddings = HuggingFaceEmbeddings()
      index = self.pc.Index(self.index_name)
      vector_store = PineconeVectorStore(index=index, embedding=embeddings)
      uuids = [str(uuid4()) for _ in range(len(docs))]
      vector_store.add_documents(documents=docs, ids=uuids)


    # TODO: To be implemented
    def generate(self, query):
        # print(f"Generating with system prompt: {self.Employee_Template}")
        relevant_docs = self.get_relevant_docs(query)
        query = query + " try to answer from " + relevant_docs
        print(f"Augmented Query is: {query}")
        query_response = self.full_chain.invoke({"question": query})
        return query_response

    #Implement as per paper 1 with self generated text and break down of question into subsequent parts
    def Augment_prompt(self, query):
      pass


    # So this is what i had a theory about
    def get_relevant_docs(self,query):
        augmented_prompt = self.get_relevant_docs_chain.invoke({"question": query})
        documents = [
            "Code-of-conduct", "Compensation-Benefits-Guide", "Employee-appraisal-form",
            "Employee-Handbook", "Employee-Termination-Policy", "Health-and-Safety-Guidelines",
            "Onboarding-Manual", "Remote-Work-Policy", "Cybersecurity-for-Employees",
            "System-Access-Control-Policy", "Technology-Devices-Policy", "Expense-Report"
        ]
        words = augmented_prompt.split()
        matches = [doc for doc in documents if doc in words]
        return ", ".join(matches[:2])


    #Helper functions:
    def format_docs(self, docs):
        return "\n\n".join([d.page_content for d in docs])


    def route(self, info):
        if "relevant" in info["Relevancy"].lower():
          # print("Question was relevant")
          return self.Employee_chain.invoke(info["question"])
        else:
          return "Your question was not relevant to our organization"

# %%
# All eval questions:

#Init
bot = EmployeeChatBot()

#Question1
question = "One of Comerica's clients is hosting an open house that includes a raffle for some free airline tickets. If I win, can I accept the tickets?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question2
question = "At City of Fond du Lac, what is the list of holidays that i can be compensated as working atleast 20 hours per week?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question3
question = "What are the details i have to add in \“Employee Information\” section of the Employee Appraisal Form for the University of Texas, and what is the Rating Key they have provided?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question4
question = "As per the Recruitment section of the employee handbook, what is my reward if i someone is recruited from my referral in a hard-to-fill role?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question5
question = "What are my duties as a supervisor, before the start date, when onboarding new employees at the university of houston?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)
# Out:
# Question is:
# One of Comerica's clients is hosting an open house that includes a raffle for some free airline tickets. If I win, can I accept the tickets?
# Augmented Query is: One of Comerica's clients is hosting an open house that includes a raffle for some free airline tickets. If I win, can I accept the tickets? try to answer from Health-and-Safety-Guidelines
#
# Answer is:
# 1. **Understand the question**: Would accepting free airline tickets offered by Comerica's client in a raffle compromise safety protocol during the work event where winning tickets are announced?
#       2. **Analyze the context**: Airline tickets themselves pose a negligible risk as the raffle occurs outside working hours with no connection to health and safety concerns. However, accepting the tickets indirectly may lead the client to incorrect assumptions that these gifts do not violate Comerica's gift policy.
#       3. **Evaluate implications**: Though immediate hazards are unforeseen, potential ethics implications necessitate abiding by company policies which would restrict accepting free gifts of notable value such as tickets in these instances without prior review and approval. To reduce assumptions around questionable ethical practices, it is advisable to seek advice on the situation, even if not directly associated with Health and Safety protocol.
#       4. **Provide the answer**: In accordance with Comerica's ethics policy, employees cannot accept prizes, like free airline tickets, from client parties and must adhere to this policy when offered such a prize in a scenario such as an open house with the possibility of winning them in a raffle. Reaching out to your supervisor for clarification and guidance is recommend as a way to comply, minimizing potential accusations of unaccepted gifts or unethical behaviors.
#       5. **Reflection**: My response demonstrates a focus on employee ethical responsibility to avoid any perceived violations of gift policies at Comerica and emphasizes the importance of aligning actions with explicit company policy whenever applicable situations arise.
# Question is:
# At City of Fond du Lac, what is the list of holidays that i can be compensated as working atleast 20 hours per week?
# Augmented Query is: At City of Fond du Lac, what is the list of holidays that i can be compensated as working atleast 20 hours per week? try to answer from Employee-Handbook, Health-and-Safety-Guidelines
#
# Answer is:
#  According to the provided context from the Employee Handbook, eligible employees may receive compensation for the following holidays based on working at least 20 hours per week:
#        - New Years Day
#        - Labor Day
#        - Memorial Day
#        - Thanksgiving Day
#        - Christmas Day
#        - Christmas Eve (on December 24)
#        - Independence Day
#        - Day after Thanksgiving
#        - New Years Eve (on December 31)If a holiday falls on either Saturday or Sunday, it shall be replaced with either Friday (for Holidays falling on Saturdays) or observed the Monday (for Holidays falling on Sundays). To further validate whether or not certain holidays or leave periods pertain to temporary or part-time employees, readers are directed to review health-related guidelines accordingly.
# Question is:
# What are the details i have to add in \“Employee Information\” section of the Employee Appraisal Form for the University of Texas, and what is the Rating Key they have provided?
# Augmented Query is: What are the details i have to add in \“Employee Information\” section of the Employee Appraisal Form for the University of Texas, and what is the Rating Key they have provided? try to answer from
#
# Answer is:
# 1. **Understand the question**: The employee needs help completing the ‘Employee Information’ section of the Employee Appraisal Form at the University of Texas and asks for help in understanding the Rating Key.
#       2. **Analyze the context**: This section requires providing the appraisees' personal details (name, employee ID, etc.), title or job position within the context of the Department, position level whether the appraised is a supervisor, and the type of evaluation being done (probation, ending probation, or annual review). Additionally, the Rating Key used evaluates various job functions, with the five possible rating ranges - 5 being Excellent (EP - 5), Exceptional Periodic (PE - 4), Satisfactory (SP - 3), Inconsistent (IP - 2), and '-not yet found, which I’m filling in with Undetermined (Inc.) or 'INC.' In this example for simplicity reasons, the last two performance ratings do not correspond to all performance areas. The evaluation information section then requires information specific to the appraised’ performance based on their essential job requirements for the department. The final sections refer to additional job performance characteristics, each accompanied by guidelines and asking evaluators to cite examples from an appraisal cycle period.
#       3. **Evaluate implications**: Being attentive to the details and context is essential to construct meaningful self-reflection for improved job performance. Failing to accurately document and consider various essential duties in performance can result in unintentional biases and a weak appraisal, as well as making incorrect judgements on specific performance examples referenced
#       4. **Provide the answer**: The essential information requested for the 'Employee Information' section requires the appraisees' full name (First Name and Surname last), corresponding employee id, position, department assignment if pertinent, 'Is this person a supervisor?' box checked or no, Appraisal Period Start Date and End date(specific to each cycle period) type – annual or other defined cycle – along with either Probation, Ending Probation or 'not yet determined as this being their first evaluation.' As for the Rating Key section of the employee evaluational form I provided you with specifics from UH University evaluatable parameters you will see that the University has a five star rating system similar to UT but you should contact their superiors directly for specific names or
# Question is:
# As per the Recruitment section of the employee handbook, what is my reward if i someone is recruited from my referral in a hard-to-fill role?
# Augmented Query is: As per the Recruitment section of the employee handbook, what is my reward if i someone is recruited from my referral in a hard-to-fill role? try to answer from
#
# Answer is:
# 1. **Understand the question**: If an referred candidate is hired in a hard-to-fill role such as a Data Scientist, the reward an employee would receive.
#       2. **Analyze the context**: Upon careful reading of the provided employment policy ( Recruitment ), rewards of 6000 or equivalent (as stated as Amazon gift coupons) to the referee for referring to such candidates.
#       3. **Evaluate implications**: Referring candidates in hard-to-fill positions such as Data Scientist results in increased bonuses to employees.
#       4. **Provide the answer**: If you successfully recruit a candidate for a hard-to-fill position like a Data Scientist, a reward of 6000, or equivalent in Amazon coupons, could potentially be granted (however, it's best to check HR or our referral program manager to confirm the terms, conditions and specifics.) Note that these rewards may be susceptible to taxation. The terms can often vary from company to company, so be mindful to ask appropriate question and check thoroughly as to the guidelines that your particular company will adhere when distributing such bonuses.
#       5. **Reflection**: Based on review of provided context (Recruitment section in our current employee policy ), potential for higher bonuses can be established for positions classified with certain level of employment scarcity known as "hard-to-fill roles", resulting in possible compensation increase if successfully filling one such available role by providing a suitable candidate match.
# Question is:
# What are my duties as a supervisor, before the start date, when onboarding new employees at the university of houston?
# Augmented Query is: What are my duties as a supervisor, before the start date, when onboarding new employees at the university of houston? try to answer from Onboarding-Manual
#
# Answer is:
# 1. Understand the question: The user is asking for the duties specific to supervisors during the onboarding process at the university prior to the start dates of new employees.
#       2. Analyze the context: Provide a review of relevant information for my answer based on the given document, "ONBOARDING MANUAL."
#       3. Evaluate implications: Ensure compliance with university policies during onboarding processes for successful integration and high levels of employee satisfaction.
#       4. Provide the answer: Your duties include, but aren't limited to checking that background and pre-employment papers such as forms, verifications, reference checks, drug and alcohol screenings as necessary, being aware of each new team member’s start dates, and setting them up for success by welcoming them with clear instructions, scheduling, and the necessary support through an introduced buddy if required. Additionally, ensure the office, equipment, IT setups, and workplace are well-organized and ready for your new employee. This preparation ultimately boosts the chances of smoother, accelerated incorporation that also reduces risk of conflict and turnover. As there was an Onboarding Manual mentioned, following those specific guidelines would be highly relevant in conducting a sound preboarding effort. If these are insufficient or you require further specifications based on job position or particular onboarding procedures implemented at this department or faculty of University of Houston - feel free to contact HR and get more targeted information to follow through more fruitfully. A sample email with suggested welcome content has also been provided for simplicity and reference (see Section 2.A of the manual).
#       5. Reflection: My answer encompasses a thorough analysis from
#               onboarding
#               policy mentioned (ONBOARDING MANUAL) specific recommendations as a supervisor aiming for best possible practices by following policy, creating positive culture and aiding smooth incorporation, minimizing risk of friction and optimizing productivity across onboarding process for this university, focusing also on prepared IT workplaces so as not hindering the effectiveness of work upon employee's first entry on-site and enabling quicker settling to work flow after on-site arrival as mentioned through scientific findings for better team work in employee engagement and productivity.

# %%
#Question6
question = "What are the productivity measures if i want to work remotely and are there any meetings i have to attend if i am working remotely?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question7
question = "While on the topic of cyber security, in what ways can i be exploited via Emails?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question8
question = "what are the user access control guidelines for system access control policy of the company?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question9
question = "What are the Unacceptable use scenarios of technology devices at workforce central?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)

#Question10
question = "how can i create expense report procurement card for Concur Travel and Expense System?"
print("Question is: \n" + question)
answer = bot.generate(question)
print("\nAnswer is: \n" + answer)
# Out:
# Question is:
# What are the productivity measures if i want to work remotely and are there any meetings i have to attend if i am working remotely?
# Augmented Query is: What are the productivity measures if i want to work remotely and are there any meetings i have to attend if i am working remotely? try to answer from
#
# Answer is:
# 1. **Understand the question**: The employee desires to work remotely and wants to know about productivity measures and meetings that may be required if they decide to do so.
#       2. **Analyze the context**: The company guidelines state remote employees must have approved workspaces, regularly submit Project Reports, and refrain from substituting Comp Time during certain company meetings. There appears to be no explicit mention of productivity measuring beyond regular meetings with supervisors and the Project Report requirement. The specific rules and processes for remote employees vary by employment levels, notably affecting consultants, Vice Presidents (VPs), and Regional remote employees in various ways.
#       (For Vice President Meeting frequency and project report information, the reader is referred back to their prior question regarding management roles and remote employees.)
#       3. **Evaluate implications**: The policy prioritizes regular communication between remote employees and their supervisors as a key factor ensuring productivity while working remotely. Attendance in certain company-sponsored meetings and weekly meetings scheduled between the employer and employee, along with Project Reports, serve as means of upholding said communication and accountability for the tasks at hand. As remote working eliminates physical interactions, the ability to take ownership of tasks and establish trust with employers is emphasized as the primary basis for success when operating virtually.
#       4. **Provide the answer**: The guidelines for your productivity as a remote employee consist mainly of regular interactions with your direct supervisor through required weekly meetings, the submission of a Project Report detailing your progress, project updates and approvals as-needed, among other items, before such scheduled meetups. These protocols apply for general employees under regular remote work conditions while detailed specifics may require further consult based on an employee’s professional level (e.g., VPs in the initial example provided). It’s important to meet attendance expectations to major company gatherings that provide insight and further direction on various projects your working on while remote, as required for regional employees based on policy and circumstances described.
#       ​
#       5. **Reflection**: My answer was aimed at providing a brief and precise description of the main guidelines remote employees of the company must adhere to in order to promote successful, flexible virtual performance while encouraging trust by highlighting that key tasks such as meetings with supervisors and detailed reports remain as stipulated, irrespective of location. In doing so, it offered an introduction to policies and protocol in case the employee desires to
# Question is:
# While on the topic of cyber security, in what ways can i be exploited via Emails?
# Augmented Query is: While on the topic of cyber security, in what ways can i be exploited via Emails? try to answer from Cybersecurity-for-Employees, System-Access-Control-Policy
#
# Answer is:
# 1. **Understand the question**: Describe common methods of cyber attacks or exploitations that occur through emails as per our Cybersecurity for Employees guide and System Access-Control Policy documents.
#
#       2. **Analyze the context**: Our system policy explicitly outlines email phishing attempts aimed at unauthorized access to sensitive employee and corporate data, often impersonating senior figures like the CEO. Factors mentioned in both context documents state these exploitations can utilize tactics ranging from spoofing sender addresses to delivering harmful URLs and malicious email attachments such as phishing mails, Trojans and ads hosting loopholes for intruder exploitation.
#
#       3. **Evaluate implications**: Familiarity with prevalent types of exploitation through emails is important so that cyber threats are acknowledged, detected quickly and their impacts mitigated promptly by following prescribed safety measures like keeping abreast of new security practices and always inquisitive when dealing with questionable emails.
#
#       4. **Provide the answer**: Typically via the guidance found in 'Cybersecurity-for-Employees' and ‘System Access-Control Policy’, the potential means of exploitation within your professional email domain comprise email spying attempts in the guise of senior officials or partners, known as "phishing". Phishing attacks may seek access to private information through dubious email links directing you to dubious and compromised websites, email add-ons disguising harmful elements, including embedded ads that might enable exploitation, sender spoofing as well as email hijacking which might have the impact of compromising vital network systems, or introducing unwanted malware components within the system.
#
#       5. **Reflection**: In this analysis of various risks posed via questionable email interactions derived from contextual information available from 'Cybersecurity-for-Employees' and ‘System Access-Control Policy,' four salient features stand out: Embedding suspicious links, trojan installation and advertisement phishing via harmful emails and dubious adware. The objective of cybersecurity education involves enabling individuals and groups to make well informed decisions when processing corporate communications—to prioritize their own safety first, as well that of their fellow associates and the systems they work on; therefore, a cautious and skeptical mindset becomes essential when interacting within these digital realms
# Question is:
# what are the user access control guidelines for system access control policy of the company?
# Augmented Query is: what are the user access control guidelines for system access control policy of the company? try to answer from Cybersecurity-for-Employees, System-Access-Control-Policy
#
# Answer is:
# Your question was not relevant to our organization
# Question is:
# What are the Unacceptable use scenarios of technology devices at workforce central?
# Augmented Query is: What are the Unacceptable use scenarios of technology devices at workforce central? try to answer from Technology-Devices-Policy
#
# Answer is:
#  Based on the provided Technology Devices Acceptable Use & Security Policy, some examples of Unacceptable use scenarios for WorkForce Central technology devices include the following:
#
#         1. Downloading and/or distributing software or any unauthorized multimedia files, including songs, pictures, or videos that you do not have permission to access or share. This might compromise network security or cause legal concerns relating to intellectual property violations.
#         2. Installing third-party software or modifying system applications unless approved in writing by the company's IT team. These could interfere with operational capabilities or compromise security features, potentially introducing undesirable malware or viruses.
#         3. Use and management of Personal Cloud Services. Using Personal Cloud Service accounts, platforms, or devices during work hours, including storage of private data using work resources and using WorkForce Central technology devices, such as company issued phones or other internet enabled devices like tablets or smart watches without written consent, may raise compliance concerns.
#         4. Inappropriate and illegal usage, for instance: conducting criminal activities, distributing harmful emails or computer programs, or participating in acts deemed to harass employees. Engaging in such acts on any medium can also have negative repercussions on workplace dynamics and productivity.
#         5. Solicitation or mass mailing of other emails with intentions for harassing users or hoax campaigns (such as chain eails or pyramid schemes) - this is strictly against the acceptable use guideline outlined in the policy. Such actions could also result in flooding WorkForce Central's email network, causing outages for users.
#
# The complete policy document can be viewed on WorkForce-Centrals’s organization's website at https://workforce-central.org/aboutpolicies/ to give a more comprehensive understanding about usage and management of technology equipment and policies specific to inventory at workforce central.
#          For further references on the specific policy related requirements governing the purchase and inventory controls for technology items, visit the Workforce Central’s Property Management and Inventory policy at https://workforce-central.org/aboutpolicies/(reference number left purposefully blank - as the text in the policy provided a referral instead of explicit listing within main bullet of the specific Property and Supply control Policy) as well. To stay compliant, all employees, as well as all personnel affiliated with WorkForce Central sub-recipients, are bound by this strict ad
# Question is:
# how can i create expense report procurement card for Concur Travel and Expense System?
# Augmented Query is: how can i create expense report procurement card for Concur Travel and Expense System? try to answer from
#
# Answer is:
# Your question was not relevant to our organization
